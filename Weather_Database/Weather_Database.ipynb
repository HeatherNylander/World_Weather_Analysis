# %% [markdown]
# # Deliverable 1

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import matplotlib.pyplot as plt

# %%
#Create a new set of 2,000 random latitudes and longitudes.

lats = np.random.uniform(-90.000,90.000,size=2000)
lngs = np.random.uniform(-180.000,180.000,size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lisakovsk
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | chake chake
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | bumba
# Processing Record 7 of Set 1 | pedasi
# Processing Record 8 of Set 1 | bathsheba
# Processing Record 9 of Set 1 | nabire
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | vardo
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | shima
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | adrar
# Processing Record 17 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 1 | san patricio
# Processing Record 19 of Set 1 | iranshahr
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | fairbanks
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | zhigansk
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | vostok
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | ilulissat
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | yazman
# Processing Record 31 of Set 1 | gurupi
# Processing Record 32 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 1 | bloomington
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | lompoc
# Processing Record 36 of Set 1 | pisco
# Processing Record 37 of Set 1 | cherskiy
# Processing Record 38 of Set 1 | marovoay
# Processing Record 39 of Set 1 | cavalcante
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | alice springs
# Processing Record 42 of Set 1 | gravdal
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | broken hill
# Processing Record 45 of Set 1 | namibe
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | vila velha
# Processing Record 48 of Set 1 | cairns
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | mangrol
# Processing Record 1 of Set 2 | ostrovnoy
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | tombouctou
# Processing Record 4 of Set 2 | rikitea
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | mataura
# Processing Record 7 of Set 2 | camacha
# Processing Record 8 of Set 2 | izberbash
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | nosy varika
# Processing Record 11 of Set 2 | tuktoyaktuk
# Processing Record 12 of Set 2 | iqaluit
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | berlevag
# Processing Record 15 of Set 2 | kavieng
# Processing Record 16 of Set 2 | komsomolskiy
# Processing Record 17 of Set 2 | yatou
# Processing Record 18 of Set 2 | fortuna
# Processing Record 19 of Set 2 | magugu
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | makokou
# Processing Record 23 of Set 2 | bissau
# Processing Record 24 of Set 2 | necochea
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | juneau
# Processing Record 27 of Set 2 | narsaq
# Processing Record 28 of Set 2 | kendari
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 30 of Set 2 | faanui
# Processing Record 31 of Set 2 | awjilah
# Processing Record 32 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 2 | esperance
# Processing Record 34 of Set 2 | khandbari
# Processing Record 35 of Set 2 | airai
# Processing Record 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 2 | bengkulu
# Processing Record 38 of Set 2 | ripoll
# Processing Record 39 of Set 2 | provideniya
# Processing Record 40 of Set 2 | eureka
# Processing Record 41 of Set 2 | nesna
# Processing Record 42 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 43 of Set 2 | norman wells
# Processing Record 44 of Set 2 | hobart
# Processing Record 45 of Set 2 | tambun
# Processing Record 46 of Set 2 | gizo
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 2 | sanchor
# Processing Record 50 of Set 2 | mayo
# Processing Record 1 of Set 3 | bucerias
# Processing Record 2 of Set 3 | haapu
# City not found. Skipping...
# Processing Record 3 of Set 3 | saint-philippe
# Processing Record 4 of Set 3 | bardsir
# Processing Record 5 of Set 3 | hambantota
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | hasaki
# Processing Record 8 of Set 3 | phon
# Processing Record 9 of Set 3 | geraldton
# Processing Record 10 of Set 3 | new norfolk
# Processing Record 11 of Set 3 | kupang
# Processing Record 12 of Set 3 | spornoye
# Processing Record 13 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | bossembele
# City not found. Skipping...
# Processing Record 16 of Set 3 | catia la mar
# Processing Record 17 of Set 3 | ribeira grande
# Processing Record 18 of Set 3 | upernavik
# Processing Record 19 of Set 3 | usinsk
# Processing Record 20 of Set 3 | key largo
# Processing Record 21 of Set 3 | saldanha
# Processing Record 22 of Set 3 | gorontalo
# Processing Record 23 of Set 3 | tafo
# Processing Record 24 of Set 3 | qaanaaq
# Processing Record 25 of Set 3 | puerto escondido
# Processing Record 26 of Set 3 | aksarka
# Processing Record 27 of Set 3 | newport
# Processing Record 28 of Set 3 | zeya
# Processing Record 29 of Set 3 | nishihara
# Processing Record 30 of Set 3 | luderitz
# Processing Record 31 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 3 | hervey bay
# Processing Record 33 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 3 | yangjiang
# Processing Record 35 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 3 | padang
# Processing Record 38 of Set 3 | ossora
# Processing Record 39 of Set 3 | castro
# Processing Record 40 of Set 3 | cockburn town
# Processing Record 41 of Set 3 | isangel
# Processing Record 42 of Set 3 | shingu
# Processing Record 43 of Set 3 | nome
# Processing Record 44 of Set 3 | thinadhoo
# Processing Record 45 of Set 3 | labytnangi
# Processing Record 46 of Set 3 | bagdarin
# Processing Record 47 of Set 3 | stepnyak
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | darhan
# Processing Record 50 of Set 3 | saint george
# Processing Record 1 of Set 4 | orodara
# Processing Record 2 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 3 of Set 4 | alyangula
# Processing Record 4 of Set 4 | monterey
# Processing Record 5 of Set 4 | basoko
# Processing Record 6 of Set 4 | ilhabela
# Processing Record 7 of Set 4 | gold coast
# Processing Record 8 of Set 4 | batticaloa
# Processing Record 9 of Set 4 | kaeo
# Processing Record 10 of Set 4 | haines junction
# Processing Record 11 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 4 | teahupoo
# Processing Record 13 of Set 4 | sao filipe
# Processing Record 14 of Set 4 | sacramento
# Processing Record 15 of Set 4 | constitucion
# Processing Record 16 of Set 4 | thompson
# Processing Record 17 of Set 4 | tessalit
# Processing Record 18 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 4 | vasilsursk
# Processing Record 20 of Set 4 | rongu
# City not found. Skipping...
# Processing Record 21 of Set 4 | dudinka
# Processing Record 22 of Set 4 | abu samrah
# Processing Record 23 of Set 4 | garissa
# Processing Record 24 of Set 4 | waipawa
# Processing Record 25 of Set 4 | dobryanka
# Processing Record 26 of Set 4 | chulym
# Processing Record 27 of Set 4 | severo-kurilsk
# Processing Record 28 of Set 4 | half moon bay
# Processing Record 29 of Set 4 | lata
# Processing Record 30 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 4 | celestun
# Processing Record 32 of Set 4 | svetlyy
# Processing Record 33 of Set 4 | nisia floresta
# Processing Record 34 of Set 4 | oussouye
# Processing Record 35 of Set 4 | patos
# Processing Record 36 of Set 4 | mar del plata
# Processing Record 37 of Set 4 | georgetown
# Processing Record 38 of Set 4 | vysha
# Processing Record 39 of Set 4 | narbonne
# Processing Record 40 of Set 4 | coreau
# Processing Record 41 of Set 4 | coquimbo
# Processing Record 42 of Set 4 | tual
# Processing Record 43 of Set 4 | saskylakh
# Processing Record 44 of Set 4 | desaguadero
# Processing Record 45 of Set 4 | chihuahua
# Processing Record 46 of Set 4 | klaksvik
# Processing Record 47 of Set 4 | mount gambier
# Processing Record 48 of Set 4 | tiksi
# Processing Record 49 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 4 | oum hadjer
# Processing Record 1 of Set 5 | jacareacanga
# Processing Record 2 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 5 | chuy
# Processing Record 4 of Set 5 | burica
# City not found. Skipping...
# Processing Record 5 of Set 5 | limache
# Processing Record 6 of Set 5 | kaitangata
# Processing Record 7 of Set 5 | robertsport
# Processing Record 8 of Set 5 | honiara
# Processing Record 9 of Set 5 | pindi bhattian
# Processing Record 10 of Set 5 | khatanga
# Processing Record 11 of Set 5 | kysyl-syr
# Processing Record 12 of Set 5 | osakarovka
# Processing Record 13 of Set 5 | wuwei
# Processing Record 14 of Set 5 | sembakung
# Processing Record 15 of Set 5 | zolotukhino
# Processing Record 16 of Set 5 | yerbogachen
# Processing Record 17 of Set 5 | manaure
# Processing Record 18 of Set 5 | broome
# Processing Record 19 of Set 5 | yelnya
# Processing Record 20 of Set 5 | la sarre
# Processing Record 21 of Set 5 | ashland
# Processing Record 22 of Set 5 | muyezerskiy
# Processing Record 23 of Set 5 | goderich
# Processing Record 24 of Set 5 | razole
# Processing Record 25 of Set 5 | martapura
# Processing Record 26 of Set 5 | kralendijk
# Processing Record 27 of Set 5 | high prairie
# Processing Record 28 of Set 5 | nioro
# Processing Record 29 of Set 5 | hithadhoo
# Processing Record 30 of Set 5 | san joaquin
# Processing Record 31 of Set 5 | edd
# Processing Record 32 of Set 5 | poso
# Processing Record 33 of Set 5 | vao
# Processing Record 34 of Set 5 | tamandare
# Processing Record 35 of Set 5 | katsuura
# Processing Record 36 of Set 5 | alencon
# Processing Record 37 of Set 5 | bairiki
# Processing Record 38 of Set 5 | lasa
# Processing Record 39 of Set 5 | dingle
# Processing Record 40 of Set 5 | alofi
# Processing Record 41 of Set 5 | labuhan
# Processing Record 42 of Set 5 | iset
# Processing Record 43 of Set 5 | huilong
# Processing Record 44 of Set 5 | hostinne
# Processing Record 45 of Set 5 | grand gaube
# Processing Record 46 of Set 5 | pomabamba
# Processing Record 47 of Set 5 | xining
# Processing Record 48 of Set 5 | waling
# Processing Record 49 of Set 5 | rio grande
# Processing Record 50 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 6 | mandan
# Processing Record 2 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 3 of Set 6 | rocha
# Processing Record 4 of Set 6 | nanzhang
# Processing Record 5 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 6 of Set 6 | port hardy
# Processing Record 7 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 8 of Set 6 | axim
# Processing Record 9 of Set 6 | sao paulo de olivenca
# Processing Record 10 of Set 6 | pacific grove
# Processing Record 11 of Set 6 | lipin bor
# Processing Record 12 of Set 6 | tiarei
# Processing Record 13 of Set 6 | jhalida
# Processing Record 14 of Set 6 | nizhnevartovsk
# Processing Record 15 of Set 6 | santa cruz
# Processing Record 16 of Set 6 | ponta do sol
# Processing Record 17 of Set 6 | codrington
# Processing Record 18 of Set 6 | ipoti
# Processing Record 19 of Set 6 | te anau
# Processing Record 20 of Set 6 | galveston
# Processing Record 21 of Set 6 | longyearbyen
# Processing Record 22 of Set 6 | maryville
# Processing Record 23 of Set 6 | kalghatgi
# Processing Record 24 of Set 6 | margate
# Processing Record 25 of Set 6 | mtambile
# Processing Record 26 of Set 6 | la tuque
# Processing Record 27 of Set 6 | umba
# Processing Record 28 of Set 6 | ardakan
# Processing Record 29 of Set 6 | kushima
# Processing Record 30 of Set 6 | srednekolymsk
# Processing Record 31 of Set 6 | bayan
# Processing Record 32 of Set 6 | yershichi
# Processing Record 33 of Set 6 | thunder bay
# Processing Record 34 of Set 6 | nelson bay
# Processing Record 35 of Set 6 | ternate
# Processing Record 36 of Set 6 | aklavik
# Processing Record 37 of Set 6 | nhulunbuy
# Processing Record 38 of Set 6 | sao miguel do araguaia
# Processing Record 39 of Set 6 | matagami
# Processing Record 40 of Set 6 | payo
# Processing Record 41 of Set 6 | coihaique
# Processing Record 42 of Set 6 | carnarvon
# Processing Record 43 of Set 6 | asau
# Processing Record 44 of Set 6 | yerofey pavlovich
# Processing Record 45 of Set 6 | kampene
# Processing Record 46 of Set 6 | bo rai
# Processing Record 47 of Set 6 | cabo san lucas
# Processing Record 48 of Set 6 | victoria
# Processing Record 49 of Set 6 | zatoka
# Processing Record 50 of Set 6 | pevek
# Processing Record 1 of Set 7 | sioux lookout
# Processing Record 2 of Set 7 | parabel
# Processing Record 3 of Set 7 | ambilobe
# Processing Record 4 of Set 7 | diego de almagro
# Processing Record 5 of Set 7 | mezen
# Processing Record 6 of Set 7 | palaiokhora
# City not found. Skipping...
# Processing Record 7 of Set 7 | bulgan
# Processing Record 8 of Set 7 | sun city west
# Processing Record 9 of Set 7 | hovd
# Processing Record 10 of Set 7 | ganzhou
# Processing Record 11 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 7 | leshukonskoye
# Processing Record 13 of Set 7 | molochnoye
# Processing Record 14 of Set 7 | salisbury
# Processing Record 15 of Set 7 | auray
# Processing Record 16 of Set 7 | baijiantan
# Processing Record 17 of Set 7 | waingapu
# Processing Record 18 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 7 | campbell river
# Processing Record 20 of Set 7 | port arthur
# Processing Record 21 of Set 7 | hwange
# Processing Record 22 of Set 7 | zhanaozen
# Processing Record 23 of Set 7 | shimoda
# Processing Record 24 of Set 7 | belmonte
# Processing Record 25 of Set 7 | tripoli
# Processing Record 26 of Set 7 | east london
# Processing Record 27 of Set 7 | ola
# Processing Record 28 of Set 7 | cascavel
# Processing Record 29 of Set 7 | sao joao da barra
# Processing Record 30 of Set 7 | vestmannaeyjar
# Processing Record 31 of Set 7 | toamasina
# Processing Record 32 of Set 7 | of
# City not found. Skipping...
# Processing Record 33 of Set 7 | wangou
# Processing Record 34 of Set 7 | paamiut
# Processing Record 35 of Set 7 | pangai
# Processing Record 36 of Set 7 | riyadh
# Processing Record 37 of Set 7 | nouakchott
# Processing Record 38 of Set 7 | omboue
# Processing Record 39 of Set 7 | abha
# Processing Record 40 of Set 7 | iquitos
# Processing Record 41 of Set 7 | port elizabeth
# Processing Record 42 of Set 7 | amapa
# Processing Record 43 of Set 7 | strezhevoy
# Processing Record 44 of Set 7 | souillac
# Processing Record 45 of Set 7 | pemba
# Processing Record 46 of Set 7 | solnechnyy
# Processing Record 47 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 7 | hualmay
# Processing Record 49 of Set 7 | ixtapa
# Processing Record 50 of Set 7 | sosnogorsk
# Processing Record 1 of Set 8 | zabolotovka
# Processing Record 2 of Set 8 | jasper
# Processing Record 3 of Set 8 | fukue
# Processing Record 4 of Set 8 | roseburg
# Processing Record 5 of Set 8 | henties bay
# Processing Record 6 of Set 8 | ancud
# Processing Record 7 of Set 8 | raudeberg
# Processing Record 8 of Set 8 | blagoyevo
# Processing Record 9 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 8 | chuncheng
# Processing Record 11 of Set 8 | kidal
# Processing Record 12 of Set 8 | caraballeda
# Processing Record 13 of Set 8 | anadyr
# Processing Record 14 of Set 8 | worthing
# Processing Record 15 of Set 8 | chipinge
# Processing Record 16 of Set 8 | perth
# Processing Record 17 of Set 8 | ahipara
# Processing Record 18 of Set 8 | inhambane
# Processing Record 19 of Set 8 | la ronge
# Processing Record 20 of Set 8 | baragua
# Processing Record 21 of Set 8 | yar-sale
# Processing Record 22 of Set 8 | toowoomba
# Processing Record 23 of Set 8 | praxedis guerrero
# Processing Record 24 of Set 8 | hamilton
# Processing Record 25 of Set 8 | the valley
# Processing Record 26 of Set 8 | bonavista
# Processing Record 27 of Set 8 | semey
# Processing Record 28 of Set 8 | kamenskiy
# Processing Record 29 of Set 8 | beira
# Processing Record 30 of Set 8 | nanortalik
# Processing Record 31 of Set 8 | afantou
# Processing Record 32 of Set 8 | srandakan
# Processing Record 33 of Set 8 | ust-kut
# Processing Record 34 of Set 8 | naze
# Processing Record 35 of Set 8 | valleyview
# Processing Record 36 of Set 8 | mata
# Processing Record 37 of Set 8 | olafsvik
# Processing Record 38 of Set 8 | pangnirtung
# Processing Record 39 of Set 8 | groton
# Processing Record 40 of Set 8 | muzhi
# Processing Record 41 of Set 8 | along
# Processing Record 42 of Set 8 | palana
# Processing Record 43 of Set 8 | ayr
# Processing Record 44 of Set 8 | batemans bay
# Processing Record 45 of Set 8 | grindavik
# Processing Record 46 of Set 8 | puerto lopez
# Processing Record 47 of Set 8 | teguise
# Processing Record 48 of Set 8 | comodoro rivadavia
# Processing Record 49 of Set 8 | trenggalek
# Processing Record 50 of Set 8 | lock haven
# Processing Record 1 of Set 9 | yining
# Processing Record 2 of Set 9 | quetzaltepec
# City not found. Skipping...
# Processing Record 3 of Set 9 | aktau
# Processing Record 4 of Set 9 | fershampenuaz
# Processing Record 5 of Set 9 | miri
# Processing Record 6 of Set 9 | viedma
# Processing Record 7 of Set 9 | sitka
# Processing Record 8 of Set 9 | brekstad
# Processing Record 9 of Set 9 | kruisfontein
# Processing Record 10 of Set 9 | zhezkazgan
# Processing Record 11 of Set 9 | wabrzezno
# Processing Record 12 of Set 9 | mutoko
# Processing Record 13 of Set 9 | alekseyevsk
# Processing Record 14 of Set 9 | bogorodskoye
# Processing Record 15 of Set 9 | price
# Processing Record 16 of Set 9 | taltal
# Processing Record 17 of Set 9 | torrington
# Processing Record 18 of Set 9 | hofn
# Processing Record 19 of Set 9 | quang ngai
# Processing Record 20 of Set 9 | kiunga
# Processing Record 21 of Set 9 | gibara
# Processing Record 22 of Set 9 | koungou
# Processing Record 23 of Set 9 | karatuzskoye
# Processing Record 24 of Set 9 | lagos
# Processing Record 25 of Set 9 | dikson
# Processing Record 26 of Set 9 | jinchang
# Processing Record 27 of Set 9 | teya
# Processing Record 28 of Set 9 | san pedro
# Processing Record 29 of Set 9 | kyrnasivka
# Processing Record 30 of Set 9 | lorengau
# Processing Record 31 of Set 9 | sao geraldo do araguaia
# Processing Record 32 of Set 9 | muscat
# Processing Record 33 of Set 9 | zlobin
# Processing Record 34 of Set 9 | kaduqli
# Processing Record 35 of Set 9 | peabiru
# Processing Record 36 of Set 9 | magadan
# Processing Record 37 of Set 9 | clovis
# Processing Record 38 of Set 9 | maun
# Processing Record 39 of Set 9 | kapuskasing
# Processing Record 40 of Set 9 | marawi
# Processing Record 41 of Set 9 | marzuq
# Processing Record 42 of Set 9 | clyde river
# Processing Record 43 of Set 9 | boras
# Processing Record 44 of Set 9 | cabedelo
# Processing Record 45 of Set 9 | ronda
# Processing Record 46 of Set 9 | kodinsk
# Processing Record 47 of Set 9 | lavrentiya
# Processing Record 48 of Set 9 | cervo
# Processing Record 49 of Set 9 | pratapgarh
# Processing Record 50 of Set 9 | roald
# Processing Record 1 of Set 10 | sept-iles
# Processing Record 2 of Set 10 | monduli
# Processing Record 3 of Set 10 | vredendal
# Processing Record 4 of Set 10 | husavik
# Processing Record 5 of Set 10 | makakilo city
# Processing Record 6 of Set 10 | shache
# Processing Record 7 of Set 10 | lukuledi
# Processing Record 8 of Set 10 | roebourne
# Processing Record 9 of Set 10 | sibolga
# Processing Record 10 of Set 10 | san cristobal
# Processing Record 11 of Set 10 | iquique
# Processing Record 12 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 13 of Set 10 | kirakira
# Processing Record 14 of Set 10 | kingaroy
# Processing Record 15 of Set 10 | cartagena
# Processing Record 16 of Set 10 | kota belud
# Processing Record 17 of Set 10 | kopervik
# Processing Record 18 of Set 10 | musoma
# Processing Record 19 of Set 10 | pangoa
# Processing Record 20 of Set 10 | lagoa
# Processing Record 21 of Set 10 | sabaudia
# Processing Record 22 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 10 | high rock
# Processing Record 24 of Set 10 | otavi
# Processing Record 25 of Set 10 | nieuwpoort
# Processing Record 26 of Set 10 | zdvinsk
# Processing Record 27 of Set 10 | parkes
# Processing Record 28 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 10 | izhmorskiy
# Processing Record 30 of Set 10 | melbu
# Processing Record 31 of Set 10 | hailar
# Processing Record 32 of Set 10 | palembang
# Processing Record 33 of Set 10 | amursk
# Processing Record 34 of Set 10 | igarka
# Processing Record 35 of Set 10 | tura
# Processing Record 36 of Set 10 | catamarca
# Processing Record 37 of Set 10 | rio gallegos
# Processing Record 38 of Set 10 | dhandhuka
# Processing Record 39 of Set 10 | kitimat
# Processing Record 40 of Set 10 | algeciras
# Processing Record 41 of Set 10 | portland
# Processing Record 42 of Set 10 | piet retief
# Processing Record 43 of Set 10 | manaus
# Processing Record 44 of Set 10 | iguai
# Processing Record 45 of Set 10 | lermontovka
# Processing Record 46 of Set 10 | aykhal
# Processing Record 47 of Set 10 | maldonado
# Processing Record 48 of Set 10 | inverell
# Processing Record 49 of Set 10 | bara
# Processing Record 50 of Set 10 | okakarara
# Processing Record 1 of Set 11 | umm kaddadah
# Processing Record 2 of Set 11 | egvekinot
# Processing Record 3 of Set 11 | fredericksburg
# Processing Record 4 of Set 11 | yulara
# Processing Record 5 of Set 11 | trogir
# Processing Record 6 of Set 11 | new london
# Processing Record 7 of Set 11 | nassau
# Processing Record 8 of Set 11 | lucea
# Processing Record 9 of Set 11 | mahanoro
# Processing Record 10 of Set 11 | luganville
# Processing Record 11 of Set 11 | abilene
# Processing Record 12 of Set 11 | atikokan
# Processing Record 13 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 14 of Set 11 | tazovskiy
# Processing Record 15 of Set 11 | tuy hoa
# Processing Record 16 of Set 11 | muros
# Processing Record 17 of Set 11 | leh
# Processing Record 18 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 19 of Set 11 | mayumba
# Processing Record 20 of Set 11 | bubaque
# Processing Record 21 of Set 11 | dunedin
# Processing Record 22 of Set 11 | krasnoselkup
# Processing Record 23 of Set 11 | marsh harbour
# Processing Record 24 of Set 11 | kavaratti
# Processing Record 25 of Set 11 | daru
# Processing Record 26 of Set 11 | omsukchan
# Processing Record 27 of Set 11 | karaton
# Processing Record 28 of Set 11 | catuday
# Processing Record 29 of Set 11 | petropavlovka
# Processing Record 30 of Set 11 | jadu
# Processing Record 31 of Set 11 | port augusta
# Processing Record 32 of Set 11 | kochi
# Processing Record 33 of Set 11 | tigil
# Processing Record 34 of Set 11 | brae
# Processing Record 35 of Set 11 | huarmey
# Processing Record 36 of Set 11 | vanersborg
# Processing Record 37 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 11 | wilmington
# Processing Record 39 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 40 of Set 11 | sabang
# Processing Record 41 of Set 11 | tinskoy
# Processing Record 42 of Set 11 | bilibino
# Processing Record 43 of Set 11 | tambo
# Processing Record 44 of Set 11 | marsa matruh
# Processing Record 45 of Set 11 | makurdi
# Processing Record 46 of Set 11 | san juan
# Processing Record 47 of Set 11 | caravelas
# Processing Record 48 of Set 11 | pitimbu
# Processing Record 49 of Set 11 | satara
# Processing Record 50 of Set 11 | santiago del estero
# Processing Record 1 of Set 12 | yarmouth
# Processing Record 2 of Set 12 | richards bay
# Processing Record 3 of Set 12 | saint-joseph
# Processing Record 4 of Set 12 | dongsheng
# Processing Record 5 of Set 12 | urumqi
# Processing Record 6 of Set 12 | neyyattinkara
# Processing Record 7 of Set 12 | rundu
# Processing Record 8 of Set 12 | coari
# Processing Record 9 of Set 12 | pontal do parana
# Processing Record 10 of Set 12 | twentynine palms
# Processing Record 11 of Set 12 | rawson
# Processing Record 12 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 12 | verkhnevilyuysk
# Processing Record 14 of Set 12 | brigantine
# Processing Record 15 of Set 12 | inuvik
# Processing Record 16 of Set 12 | peace river
# Processing Record 17 of Set 12 | tabulbah
# City not found. Skipping...
# Processing Record 18 of Set 12 | manakara
# Processing Record 19 of Set 12 | antalaha
# Processing Record 20 of Set 12 | salalah
# Processing Record 21 of Set 12 | marondera
# Processing Record 22 of Set 12 | sandwick
# Processing Record 23 of Set 12 | rabo de peixe
# Processing Record 24 of Set 12 | kudahuvadhoo
# Processing Record 25 of Set 12 | barcelos
# Processing Record 26 of Set 12 | masumbwe
# Processing Record 27 of Set 12 | phuket
# Processing Record 28 of Set 12 | entre rios
# Processing Record 29 of Set 12 | timizart
# Processing Record 30 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 12 | taylorville
# Processing Record 32 of Set 12 | kunming
# Processing Record 33 of Set 12 | nuuk
# Processing Record 34 of Set 12 | porto nacional
# Processing Record 35 of Set 12 | malabo
# Processing Record 36 of Set 12 | mehamn
# Processing Record 37 of Set 12 | vreed en hoop
# City not found. Skipping...
# Processing Record 38 of Set 12 | saint-leu
# Processing Record 39 of Set 12 | kahului
# Processing Record 40 of Set 12 | ravar
# Processing Record 41 of Set 12 | slonim
# Processing Record 42 of Set 12 | killybegs
# Processing Record 43 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 44 of Set 12 | ampanihy
# Processing Record 45 of Set 12 | xiamen
# Processing Record 46 of Set 12 | baghmara
# Processing Record 47 of Set 12 | derzhavinsk
# Processing Record 48 of Set 12 | kharp
# Processing Record 49 of Set 12 | mount isa
# Processing Record 50 of Set 12 | talaya
# Processing Record 1 of Set 13 | manggar
# Processing Record 2 of Set 13 | port hedland
# Processing Record 3 of Set 13 | domoni
# Processing Record 4 of Set 13 | hobyo
# Processing Record 5 of Set 13 | vondrozo
# Processing Record 6 of Set 13 | tignere
# Processing Record 7 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 8 of Set 13 | itarema
# Processing Record 9 of Set 13 | rosetta
# Processing Record 10 of Set 13 | garbolovo
# Processing Record 11 of Set 13 | tibagi
# Processing Record 12 of Set 13 | romny
# Processing Record 13 of Set 13 | hami
# Processing Record 14 of Set 13 | mersing
# Processing Record 15 of Set 13 | yantal
# Processing Record 16 of Set 13 | ewa beach
# Processing Record 17 of Set 13 | luzhou
# Processing Record 18 of Set 13 | loiza
# Processing Record 19 of Set 13 | svetlaya
# Processing Record 20 of Set 13 | shestakovo
# Processing Record 21 of Set 13 | chara
# Processing Record 22 of Set 13 | vicuna
# Processing Record 23 of Set 13 | korla
# Processing Record 24 of Set 13 | syracuse
# Processing Record 25 of Set 13 | atasu
# Processing Record 26 of Set 13 | nyurba
# Processing Record 27 of Set 13 | cootehill
# Processing Record 28 of Set 13 | ferreira do alentejo
# Processing Record 29 of Set 13 | puerto baquerizo moreno
# Processing Record 30 of Set 13 | melendugno
# Processing Record 31 of Set 13 | oboyan
# Processing Record 32 of Set 13 | nekrasovskoye
# Processing Record 33 of Set 13 | college
# Processing Record 34 of Set 13 | neuquen
# Processing Record 35 of Set 13 | buraydah
# Processing Record 36 of Set 13 | ranot
# Processing Record 37 of Set 13 | emerald
# Processing Record 38 of Set 13 | semnan
# Processing Record 39 of Set 13 | saint-augustin
# Processing Record 40 of Set 13 | ankang
# Processing Record 41 of Set 13 | san carlos de bariloche
# Processing Record 42 of Set 13 | san matias
# Processing Record 43 of Set 13 | bac lieu
# Processing Record 44 of Set 13 | sokolovo
# Processing Record 45 of Set 13 | dembi dolo
# Processing Record 46 of Set 13 | yumen
# Processing Record 47 of Set 13 | guarapari
# Processing Record 48 of Set 13 | shaoyang
# Processing Record 49 of Set 13 | ust-nera
# Processing Record 50 of Set 13 | humaita
# Processing Record 1 of Set 14 | barpeta
# Processing Record 2 of Set 14 | turki
# Processing Record 3 of Set 14 | maloy
# Processing Record 4 of Set 14 | nara
# Processing Record 5 of Set 14 | piterka
# Processing Record 6 of Set 14 | plettenberg bay
# Processing Record 7 of Set 14 | porto novo
# Processing Record 8 of Set 14 | yangambi
# Processing Record 9 of Set 14 | weifang
# Processing Record 10 of Set 14 | borzna
# Processing Record 11 of Set 14 | touros
# Processing Record 12 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 14 | pontes e lacerda
# Processing Record 14 of Set 14 | korhogo
# Processing Record 15 of Set 14 | bismarck
# Processing Record 16 of Set 14 | bad bevensen
# Processing Record 17 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 18 of Set 14 | konin
# Processing Record 19 of Set 14 | najran
# Processing Record 20 of Set 14 | son tay
# Processing Record 21 of Set 14 | bullhead city
# Processing Record 22 of Set 14 | pinerolo
# Processing Record 23 of Set 14 | ruidoso
# Processing Record 24 of Set 14 | pierre
# Processing Record 25 of Set 14 | khash
# Processing Record 26 of Set 14 | katha
# City not found. Skipping...
# Processing Record 27 of Set 14 | qingdao
# Processing Record 28 of Set 14 | leningradskiy
# Processing Record 29 of Set 14 | port hawkesbury
# Processing Record 30 of Set 14 | snasa
# Processing Record 31 of Set 14 | buala
# Processing Record 32 of Set 14 | burns lake
# Processing Record 33 of Set 14 | shaygino
# Processing Record 34 of Set 14 | teplyk
# Processing Record 35 of Set 14 | port moresby
# Processing Record 36 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 14 | belle fourche
# Processing Record 38 of Set 14 | eydhafushi
# Processing Record 39 of Set 14 | quatre cocos
# Processing Record 40 of Set 14 | savelugu
# Processing Record 41 of Set 14 | montgomery
# Processing Record 42 of Set 14 | pathein
# Processing Record 43 of Set 14 | ende
# Processing Record 44 of Set 14 | sawtell
# Processing Record 45 of Set 14 | vrangel
# Processing Record 46 of Set 14 | alexandria
# Processing Record 47 of Set 14 | tuatapere
# Processing Record 48 of Set 14 | clarence town
# Processing Record 49 of Set 14 | port blair
# Processing Record 50 of Set 14 | san clemente
# Processing Record 1 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 15 | lemesos
# City not found. Skipping...
# Processing Record 3 of Set 15 | wiwili
# Processing Record 4 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 5 of Set 15 | chulakivka
# Processing Record 6 of Set 15 | burnie
# Processing Record 7 of Set 15 | bombo
# Processing Record 8 of Set 15 | sainte-suzanne
# Processing Record 9 of Set 15 | victor harbor
# Processing Record 10 of Set 15 | katobu
# Processing Record 11 of Set 15 | cayenne
# Processing Record 12 of Set 15 | yanam
# Processing Record 13 of Set 15 | lokosovo
# Processing Record 14 of Set 15 | santa maria
# Processing Record 15 of Set 15 | los llanos de aridane
# Processing Record 16 of Set 15 | sur
# Processing Record 17 of Set 15 | odienne
# Processing Record 18 of Set 15 | mudgee
# Processing Record 19 of Set 15 | narasannapeta
# Processing Record 20 of Set 15 | dubbo
# Processing Record 21 of Set 15 | gornyak
# Processing Record 22 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 23 of Set 15 | torbay
# Processing Record 24 of Set 15 | harper
# Processing Record 25 of Set 15 | arkul
# Processing Record 26 of Set 15 | ovalle
# Processing Record 27 of Set 15 | madang
# Processing Record 28 of Set 15 | nemuro
# Processing Record 29 of Set 15 | deputatskiy
# Processing Record 30 of Set 15 | dalbandin
# Processing Record 31 of Set 15 | moussoro
# Processing Record 32 of Set 15 | avera
# Processing Record 33 of Set 15 | mao
# Processing Record 34 of Set 15 | moroni
# Processing Record 35 of Set 15 | coruripe
# Processing Record 36 of Set 15 | poronaysk
# Processing Record 37 of Set 15 | falmouth
# Processing Record 38 of Set 15 | ivdel
# Processing Record 39 of Set 15 | sikeston
# Processing Record 40 of Set 15 | ruston
# Processing Record 41 of Set 15 | panino
# Processing Record 42 of Set 15 | christchurch
# Processing Record 43 of Set 15 | mendi
# Processing Record 44 of Set 15 | mendahara
# City not found. Skipping...
# Processing Record 45 of Set 15 | quesnel
# Processing Record 46 of Set 15 | sailana
# Processing Record 47 of Set 15 | dunmore town
# Processing Record 48 of Set 15 | sechura
# Processing Record 49 of Set 15 | saint-pierre
# Processing Record 50 of Set 15 | araguaina
# Processing Record 1 of Set 16 | wooster
# Processing Record 2 of Set 16 | atar
# Processing Record 3 of Set 16 | arcata
# Processing Record 4 of Set 16 | carman
# Processing Record 5 of Set 16 | shiraz
# Processing Record 6 of Set 16 | birjand
# Processing Record 7 of Set 16 | carroll
# Processing Record 8 of Set 16 | dinghai
# Processing Record 9 of Set 16 | dzhebariki-khaya
# Processing Record 10 of Set 16 | wagar
# Processing Record 11 of Set 16 | katherine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Reorder columns 
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp","Humidity","Cloudiness","Wind Speed","Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Lisakovsk      KZ  52.5369   62.4936     41.77        71         100
# 1         Kapaa      US  22.0752 -159.3190     80.58        85          20
# 2     Jamestown      US  42.0970  -79.2353     35.19        49         100
# 3   Chake Chake      TZ  -5.2459   39.7666     79.14        73          12
# 4         Bumba      CD   2.1833   22.4667     70.18        96          98
# 5        Pedasi      PA   7.5333  -80.0333     78.06        84         100
# 6     Bathsheba      BB  13.2167  -59.5167     79.41        73          40
# 7        Nabire      ID  -3.3667  135.4833     84.67        72          38
# 8     Busselton      AU -33.6500  115.3333     63.39        75          74
# 9  Punta Arenas      CL -53.1500  -70.9167     46.51        71          75
#
#    Wind Speed Weather Description
# 0       12.10     overcast clouds
# 1       16.11          few clouds
# 2       11.50     overcast clouds
# 3        6.08          few clouds
# 4        3.80          light rain
# 5       15.46     overcast clouds
# 6       20.71    scattered clouds
# 7        4.47    scattered clouds
# 8       12.86          light rain
# 9       13.80       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
